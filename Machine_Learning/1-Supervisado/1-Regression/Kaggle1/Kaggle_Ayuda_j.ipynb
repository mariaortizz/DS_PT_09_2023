# %% [markdown]
# #### Aquí encontrarás todo lo que necesitas saber: https://www.kaggle.com/t/ab8726f0cfc84544abbae69a6be88071

# %% [markdown]
# ## Librerias

# %%
import pandas as pd

import urllib.request
from PIL import Image

# %% [markdown]
# ## Data

# %%
### Para que funcione necesitas bajarte los archivos de datos de Kaggle 
train = pd.read_csv("data/train.csv")

# %% [markdown]
# ## Data exploration

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 912 entries, 0 to 911
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         912 non-null    int64
#  1   Company           912 non-null    object
#  2   Product           912 non-null    object
#  3   TypeName          912 non-null    object
#  4   Inches            912 non-null    float64
#  5   ScreenResolution  912 non-null    object
#  6   Cpu               912 non-null    object
#  7   Ram               912 non-null    object
#  8   Memory            912 non-null    object
#  9   Gpu               912 non-null    object
#  10  OpSys             912 non-null    object
#  11  Weight            912 non-null    object
#  12  Price_euros       912 non-null    float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 92.8+ KB

# %%
train.head()
# Out:
#    laptop_ID Company            Product   TypeName  Inches  \
# 0       1104    Acer     Aspire ES1-523   Notebook    15.6
# 1        114    Dell             XPS 13  Ultrabook    13.3
# 2        172    Acer    Aspire A517-51G   Notebook    17.3
# 3        918      HP      Elitebook 820    Netbook    12.5
# 4        447  Lenovo  IdeaPad 320-15AST   Notebook    17.3
#
#                    ScreenResolution                         Cpu  Ram  \
# 0                          1366x768   AMD A8-Series 7410 2.2GHz  4GB
# 1  Quad HD+ / Touchscreen 3200x1800  Intel Core i7 7560U 2.4GHz  8GB
# 2       IPS Panel Full HD 1920x1080  Intel Core i5 8250U 1.6GHz  8GB
# 3                 Full HD 1920x1080  Intel Core i7 7500U 2.7GHz  8GB
# 4                          1600x900   AMD A6-Series 9220 2.5GHz  8GB
#
#       Memory                           Gpu       OpSys  Weight  Price_euros
# 0  500GB HDD                 AMD Radeon R5  Windows 10   2.4kg        387.0
# 1  256GB SSD  Intel Iris Plus Graphics 640  Windows 10  1.23kg       1379.0
# 2  256GB SSD          Nvidia GeForce MX150  Windows 10     3kg        854.0
# 3  512GB SSD         Intel HD Graphics 620  Windows 10  1.26kg       1483.0
# 4    1TB HDD                 AMD Radeon R4  Windows 10   2.8kg        519.0

# %%
train.tail()
# Out:
#      laptop_ID Company                               Product  TypeName  \
# 907        996  Lenovo                     IdeaPad 320-15ABR  Notebook
# 908        731    Dell                          Alienware 17    Gaming
# 909        276    Asus                             Rog Strix    Gaming
# 910        585     MSI                          GT73VR Titan    Gaming
# 911       1173      HP  15-bw002nv (A6-9220/4GB/256GB/Radeon  Notebook
#
#      Inches       ScreenResolution                           Cpu   Ram  \
# 907    15.6      Full HD 1920x1080   AMD A12-Series 9720P 3.6GHz   6GB
# 908    17.3  4K Ultra HD 3840x2160   Intel Core i7 7700HQ 2.8GHz  32GB
# 909    17.3      Full HD 1920x1080           AMD Ryzen 1700 3GHz  16GB
# 910    17.3      Full HD 1920x1080   Intel Core i7 7820HK 2.9GHz  16GB
# 911    15.6      Full HD 1920x1080  AMD A6-Series A6-9220 2.5GHz   4GB
#
#                    Memory                      Gpu       OpSys  Weight  \
# 907             256GB SSD           AMD Radeon 530  Windows 10   2.2kg
# 908    1TB SSD +  1TB HDD  Nvidia GeForce GTX 1070  Windows 10  4.36kg
# 909  256GB SSD +  1TB HDD        AMD Radeon RX 580  Windows 10   3.2kg
# 910  512GB SSD +  1TB HDD  Nvidia GeForce GTX 1070  Windows 10  4.14kg
# 911             256GB SSD           AMD Radeon 520  Windows 10  1.91kg
#
#      Price_euros
# 907       549.00
# 908      3659.40
# 909      1549.00
# 910      2729.00
# 911       478.89

# %%
train.select_dtypes(include='number').corr()
# Out:
#              laptop_ID    Inches  Price_euros
# laptop_ID     1.000000 -0.076871     0.056520
# Inches       -0.076871  1.000000     0.054903
# Price_euros   0.056520  0.054903     1.000000

# %% [markdown]
# ## Data processing

# %% [markdown]
# 1. ScreenResolution (por ej: 1920x1080 es full HD)
# 2. CPU (tipo y GHz)
# 3. GPU (tipo y número, mientras mal alto mejor por lo que vi)
# 4. Memory (llevar todo a Gb, y separa entre HHD y SSD)

# %%
train.columns
# Out:
# Index(['laptop_ID', 'Company', 'Product', 'TypeName', 'Inches',
#        'ScreenResolution', 'Cpu', 'Ram', 'Memory', 'Gpu', 'OpSys', 'Weight',
#        'Price_euros'],
#       dtype='object')

# %%
train['Memory'].unique()
# Out:
# array(['500GB HDD', '256GB SSD', '512GB SSD', '1TB HDD', '1.0TB Hybrid',
#        '128GB SSD +  1TB HDD', '256GB SSD +  1TB HDD', '128GB SSD',
#        '256GB SSD +  500GB HDD', '256GB Flash Storage',
#        '512GB SSD +  1TB HDD', '32GB Flash Storage', '64GB Flash Storage',
#        '64GB SSD', '512GB SSD +  256GB SSD', '1TB SSD', '180GB SSD',
#        '128GB SSD +  2TB HDD', '128GB Flash Storage', '2TB HDD',
#        '1TB HDD +  1TB HDD', '32GB SSD', '16GB Flash Storage',
#        '256GB SSD +  256GB SSD', '512GB SSD +  2TB HDD', '16GB SSD',
#        '256GB SSD +  2TB HDD', '512GB Flash Storage', '508GB Hybrid',
#        '64GB Flash Storage +  1TB HDD', '512GB SSD +  512GB SSD',
#        '1TB SSD +  1TB HDD'], dtype=object)

# %%
train[train['OpSys'] == 'No OS']
# Out:
#      laptop_ID Company                                Product   TypeName  \
# 6           63  Lenovo                     IdeaPad 520S-14IKB   Notebook
# 14         272  Lenovo                     IdeaPad 320-15IKBN   Notebook
# 15         196  Xiaomi                            Mi Notebook  Ultrabook
# 40         176  Lenovo                      IdeaPad 320-15AST   Notebook
# 67         601  Lenovo  V320-17ISK (i3-6006U/4GB/500GB/FHD/No   Notebook
# 83         310  Lenovo                      IdeaPad 320-15IAP   Notebook
# 108        554  Lenovo    V310-15ISK (i5-6200U/4GB/1TB/FHD/No   Notebook
# 132         19  Lenovo                      IdeaPad 320-15IKB   Notebook
# 133        792  Lenovo                      IdeaPad 110-15IBR   Notebook
# 155        534  Lenovo                      IdeaPad 320-15ISK   Notebook
# 188       1170  Lenovo        B51-80 (i5-6200U/8GB/1TB/Radeon   Notebook
# 201        141  Lenovo                     IdeaPad 320-15IKBN   Notebook
# 215       1219  Lenovo                      IdeaPad 310-15ISK   Notebook
# 233        188  Xiaomi                            Mi Notebook   Notebook
# 248        128      HP                                 250 G6   Notebook
# 262        521  Xiaomi                            Mi Notebook   Notebook
# 317       1235  Lenovo                      IdeaPad 320-17IKB   Notebook
# 318       1191  Lenovo      V110-15ISK (i5-6200U/4GB/500GB/No   Notebook
# 349        308  Lenovo                     IdeaPad 320-15IKBN   Notebook
# 352        370  Lenovo                      IdeaPad 320-15ISK   Notebook
# 389        139  Lenovo           V110-15IAP (N3350/4GB/1TB/No   Notebook
# 400         78  Lenovo                     IdeaPad 320-15IKBN   Notebook
# 429        874  Lenovo                     Legion Y520-15IKBN     Gaming
# 437        733  Lenovo        V310-15IKB (i5-7200U/4GB/1TB/No   Notebook
# 455        870  Lenovo                      IdeaPad 110-15ISK   Notebook
# 495        634  Lenovo                     IdeaPad 320-15IKBN   Notebook
# 499       1075    Asus                      Rog G752VL-GC088D     Gaming
# 504        946      HP                                 250 G6   Notebook
# 507        470  Lenovo                     IdeaPad 510s-14IKB   Notebook
# 515        651    Asus                      ROG GL553VE-FY022     Gaming
# 539        217      HP  15-bs018nq (i3-6006U/4GB/500GB/FHD/No   Notebook
# 559        209  Lenovo                     Legion Y520-15IKBN     Gaming
# 574        125  Lenovo                     IdeaPad 320-15IKBN   Notebook
# 610        221  Lenovo                      IdeaPad 320-17IKB   Notebook
# 650       1266  Lenovo  V510-15IKB (i5-7200U/8GB/256GB/FHD/No   Notebook
# 707       1143  Lenovo                     Legion Y520-15IKBN     Gaming
# 719         12      HP                                 250 G6   Notebook
# 761         23      HP                                 255 G6   Notebook
# 770       1182      HP                                 250 G4   Notebook
# 775       1106      HP                                 250 G6   Notebook
# 782        516  Lenovo                     Legion Y520-15IKBN     Gaming
# 784        387  Lenovo  V310-15ISK (i3-6006U/4GB/128GB/FHD/No   Notebook
# 792        362  Lenovo                      IdeaPad 320-15IAP   Notebook
# 796        145  Lenovo                     Legion Y520-15IKBN     Gaming
# 828        882  Lenovo                      IdeaPad 110-15ISK   Notebook
# 881       1192  Lenovo                      IdeaPad 510-15IKB   Notebook
# 895       1168  Lenovo        V110-15ISK (i3-6006U/4GB/1TB/No   Notebook
#
#      Inches             ScreenResolution  \
# 6      14.0  IPS Panel Full HD 1920x1080
# 14     15.6            Full HD 1920x1080
# 15     13.3  IPS Panel Full HD 1920x1080
# 40     15.6                     1366x768
# 67     17.3            Full HD 1920x1080
# 83     15.6                     1366x768
# 108    15.6            Full HD 1920x1080
# 132    15.6            Full HD 1920x1080
# 133    15.6                     1366x768
# 155    15.6                     1366x768
# 188    15.6            Full HD 1920x1080
# 201    15.6            Full HD 1920x1080
# 215    15.6                     1366x768
# 233    15.6  IPS Panel Full HD 1920x1080
# 248    15.6                     1366x768
# 262    15.6  IPS Panel Full HD 1920x1080
# 317    17.3                     1600x900
# 318    15.6                     1366x768
# 349    15.6                     1366x768
# 352    15.6                     1366x768
# 389    15.6                     1366x768
# 400    15.6            Full HD 1920x1080
# 429    15.6  IPS Panel Full HD 1920x1080
# 437    15.6                     1366x768
# 455    15.6            Full HD 1920x1080
# 495    15.6            Full HD 1920x1080
# 499    17.3  IPS Panel Full HD 1920x1080
# 504    15.6                     1366x768
# 507    14.0  IPS Panel Full HD 1920x1080
# 515    15.6  IPS Panel Full HD 1920x1080
# 539    15.6            Full HD 1920x1080
# 559    15.6            Full HD 1920x1080
# 574    15.6            Full HD 1920x1080
# 610    17.3                     1600x900
# 650    15.6  IPS Panel Full HD 1920x1080
# 707    15.6  IPS Panel Full HD 1920x1080
# 719    15.6            Full HD 1920x1080
# 761    15.6                     1366x768
# 770    15.6                     1366x768
# 775    15.6                     1366x768
# 782    15.6  IPS Panel Full HD 1920x1080
# 784    15.6            Full HD 1920x1080
# 792    15.6                     1366x768
# 796    15.6  IPS Panel Full HD 1920x1080
# 828    15.6            Full HD 1920x1080
# 881    15.6            Full HD 1920x1080
# 895    15.6                     1366x768
#
#                                       Cpu   Ram                Memory  \
# 6              Intel Core i3 7130U 2.7GHz   8GB             256GB SSD
# 14             Intel Core i5 7200U 2.5GHz   4GB               1TB HDD
# 15             Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 40              AMD A6-Series 9220 2.9GHz   4GB             500GB HDD
# 67               Intel Core i3 6006U 2GHz   4GB             500GB HDD
# 83   Intel Pentium Quad Core N4200 1.1GHz   4GB               1TB HDD
# 108            Intel Core i5 6200U 2.3GHz   4GB               1TB HDD
# 132            Intel Core i3 7100U 2.4GHz   8GB               1TB HDD
# 133  Intel Celeron Quad Core N3710 1.6GHz   8GB               1TB HDD
# 155              Intel Core i3 6006U 2GHz   8GB               2TB HDD
# 188            Intel Core i5 6200U 2.3GHz   8GB               1TB HDD
# 201            Intel Core i5 7200U 2.5GHz   4GB               1TB HDD
# 215            Intel Core i7 6500U 2.5GHz   8GB             500GB HDD
# 233            Intel Core i5 8250U 1.6GHz   8GB             256GB SSD
# 248  Intel Celeron Dual Core N3060 1.6GHz   4GB             500GB HDD
# 262            Intel Core i7 8550U 1.8GHz  16GB             256GB SSD
# 317            Intel Core i5 7200U 2.5GHz   8GB               1TB HDD
# 318            Intel Core i5 6200U 2.3GHz   4GB             500GB HDD
# 349            Intel Core i5 7200U 2.5GHz   8GB               2TB HDD
# 352              Intel Core i3 6006U 2GHz   8GB             256GB SSD
# 389  Intel Celeron Dual Core N3350 1.1GHz   4GB               1TB HDD
# 400            Intel Core i5 7200U 2.5GHz   8GB               2TB HDD
# 429           Intel Core i5 7300HQ 2.5GHz   8GB               1TB HDD
# 437            Intel Core i5 7200U 2.5GHz   4GB               1TB HDD
# 455            Intel Core i3 6006U 2.0GHz   4GB               1TB HDD
# 495            Intel Core i5 7200U 2.5GHz   4GB             128GB SSD
# 499           Intel Core i7 6700HQ 2.6GHz  16GB               1TB HDD
# 504  Intel Celeron Dual Core N3060 1.6GHz   4GB               1TB HDD
# 507            Intel Core i7 7500U 2.7GHz   8GB             512GB SSD
# 515           Intel Core i7 7700HQ 2.8GHz   8GB               1TB HDD
# 539              Intel Core i3 6006U 2GHz   4GB             500GB HDD
# 559           Intel Core i7 7700HQ 2.8GHz  16GB             512GB SSD
# 574            Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 610            Intel Core i5 7200U 2.5GHz   8GB               1TB HDD
# 650            Intel Core i5 7200U 2.5GHz   8GB             256GB SSD
# 707           Intel Core i5 7300HQ 2.5GHz   8GB  128GB SSD +  1TB HDD
# 719              Intel Core i3 6006U 2GHz   4GB             500GB HDD
# 761          AMD E-Series E2-9000e 1.5GHz   4GB             500GB HDD
# 770            Intel Core i5 6200U 2.3GHz   4GB             500GB HDD
# 775              Intel Core i3 6006U 2GHz   4GB               1TB HDD
# 782           Intel Core i7 7700HQ 2.8GHz   8GB  256GB SSD +  1TB HDD
# 784              Intel Core i3 6006U 2GHz   4GB             128GB SSD
# 792  Intel Celeron Dual Core N3350 1.1GHz   4GB               1TB HDD
# 796           Intel Core i7 7700HQ 2.8GHz   8GB             256GB SSD
# 828              Intel Core i3 6006U 2GHz   4GB               1TB HDD
# 881            Intel Core i7 7500U 2.7GHz   8GB               1TB HDD
# 895            Intel Core i3 6006U 2.0GHz   4GB               1TB HDD
#
#                             Gpu  OpSys  Weight  Price_euros
# 6         Intel HD Graphics 620  No OS   1.7kg       599.00
# 14        Intel HD Graphics 620  No OS   2.2kg       467.00
# 15         Nvidia GeForce MX150  No OS   1.3kg       999.90
# 40       AMD Radeon R4 Graphics  No OS   2.2kg       309.00
# 67        Intel HD Graphics 520  No OS   2.8kg       529.00
# 83        Intel HD Graphics 505  No OS   2.2kg       359.99
# 108       Intel HD Graphics 520  No OS  2.15kg       462.35
# 132        Nvidia GeForce 940MX  No OS   2.2kg       499.00
# 133       Intel HD Graphics 405  No OS   2.2kg       329.00
# 155       Nvidia GeForce 920MX   No OS   2.2kg       459.00
# 188          AMD Radeon R5 M330  No OS  2.32kg       599.00
# 201        Nvidia GeForce 920MX  No OS   2.2kg       499.00
# 215        Nvidia GeForce 920MX  No OS   2.2kg       629.00
# 233        Nvidia GeForce MX150  No OS  1.95kg      1199.00
# 248       Intel HD Graphics 400  No OS  1.86kg       259.00
# 262        Nvidia GeForce MX150  No OS  1.95kg      1399.95
# 317       Intel HD Graphics 620  No OS   2.8kg       539.00
# 318       Intel HD Graphics 520  No OS   2.1kg       398.00
# 349        Nvidia GeForce 940MX  No OS   2.2kg       549.00
# 352       Nvidia GeForce 920MX   No OS   2.2kg       499.00
# 389       Intel HD Graphics 500  No OS   1.9kg       252.36
# 400       Intel HD Graphics 620  No OS   2.2kg       519.00
# 429     Nvidia GeForce GTX 1050  No OS   2.5kg      1017.00
# 437       Intel HD Graphics 620  No OS   1.9kg       489.90
# 455       Intel HD Graphics 520  No OS   2.2kg       469.00
# 495       Intel HD Graphics 620  No OS   2.2kg       468.00
# 499     Nvidia GeForce GTX 965M  No OS     4kg       998.00
# 504       Intel HD Graphics 400  No OS  1.86kg       288.90
# 507          AMD Radeon R7 M460  No OS   1.5kg       799.00
# 515  Nvidia GeForce GTX 1050 Ti  No OS   2.5kg      1169.00
# 539       Intel HD Graphics 520  No OS   2.1kg       349.00
# 559     Nvidia GeForce GTX 1060  No OS   2.4kg      1398.00
# 574        Nvidia GeForce 940MX  No OS   2.2kg       629.00
# 610    Nvidia GeForce GTX 940MX  No OS   2.8kg       589.00
# 650       Intel HD Graphics 620  No OS   2.3kg       573.00
# 707     Nvidia GeForce GTX 1060  No OS   2.4kg       989.00
# 719       Intel HD Graphics 520  No OS  1.86kg       344.99
# 761               AMD Radeon R2  No OS  1.86kg       258.00
# 770       Intel HD Graphics 520  No OS   2.1kg       476.99
# 775       Intel HD Graphics 520  No OS  1.86kg       345.99
# 782     Nvidia GeForce GTX 1060  No OS   2.4kg      1149.00
# 784       Intel HD Graphics 520  No OS  1.85kg       403.50
# 792       Intel HD Graphics 500  No OS   2.2kg       321.99
# 796    Nvidia GeForce GTX 1050M  No OS   2.4kg       869.00
# 828          AMD Radeon R5 M430  No OS   2.2kg       479.00
# 881        Nvidia GeForce 940MX  No OS   2.2kg       709.00
# 895       Intel HD Graphics 520  No OS   1.9kg       339.00

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 train.corr(include = 'number')
#
# TypeError: DataFrame.corr() got an unexpected keyword argument 'include'

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Pasos que si o si debéis realizar para poder participar en la competición:

# %% [markdown]
# ### 1. Definir X e y

# %%
train = train[['laptop_ID','Inches','Price_euros']]

# %%
train
# Out:
#      laptop_ID  Inches  Price_euros
# 0         1104    15.6       387.00
# 1          114    13.3      1379.00
# 2          172    17.3       854.00
# 3          918    12.5      1483.00
# 4          447    17.3       519.00
# ..         ...     ...          ...
# 907        996    15.6       549.00
# 908        731    17.3      3659.40
# 909        276    17.3      1549.00
# 910        585    17.3      2729.00
# 911       1173    15.6       478.89
#
# [912 rows x 3 columns]

# %%
X = train.drop(['Price_euros'], axis=1)
y = train['Price_euros'].copy()
X.shape
# Out:
# (912, 2)

# %%
y.shape
# Out:
# (912,)

# %% [markdown]
# ### 2. Dividir X_train, X_test, y_train, y_test

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 42)

# %%
X_train
# Out:
#      laptop_ID  Inches
# 25          26    15.6
# 84         776    15.6
# 10        1263    15.6
# 342        182    15.6
# 890        321    13.3
# ..         ...     ...
# 106        394    15.6
# 270        441    15.6
# 860        955    17.3
# 435        210    15.6
# 102        673    15.6
#
# [729 rows x 2 columns]

# %% [markdown]
# ### 3. Asignar el modelo (vacío) a una variable

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
pred = model.predict(X_test)
pred
# Out:
# array([1120.43868276, 1069.79534654, 1070.20842432, 1160.62136315,
#        1208.45577045, 1022.56227854, 1154.97198544, 1077.94506983,
#        1074.00873993, 1084.55546588, 1135.07084845, 1128.48391161,
#        1102.85078136, 1054.32277823, 1131.84884174, 1137.90208507,
#        1085.50151446, 1055.44096704, 1172.81694567, 1116.91773368,
#        1150.18028315, 1160.67245885, 1083.34429783, 1091.0275446 ,
#        1124.35313378, 1154.75565863, 1101.65688611, 1126.25329158,
#        1072.19119768, 1119.5614315 , 1060.10126111, 1030.7727385 ,
#        1176.36941461, 1144.34609849, 1117.30850377, 1081.93983336,
#        1168.60355229, 1108.67920842, 1107.55986809, 1173.31263901,
#        1169.59493897, 1106.80711591, 1139.93595413, 1140.711014  ,
#        1173.89094791, 1060.22115413, 1083.09645116, 1136.38348519,
#        1091.60585349, 1098.54556025, 1103.14857221, 1071.7047165 ,
#        1089.12738679, 1130.05360719, 1137.13623737, 1103.42909025,
#        1121.40200414, 1081.19629335, 1066.41732088, 1186.72787905,
#        1140.60609074, 1103.33726254, 1007.11316945, 1090.09070818,
#        1087.80553789, 1058.28832495, 1080.70060001, 1123.66068947,
#        1089.70569569, 1105.3200359 , 1089.14811416, 1102.10724135,
#        1200.19421478, 1070.92389903, 1133.90501849, 1095.57140021,
#        1167.72630102, 1071.28242656, 1111.92928043, 1114.66480596,
#        1090.94492904, 1138.45808627, 1154.09473417, 1116.47313604,
#        1135.83669615, 1119.37389269, 1136.63133186, 1151.83259429,
#        1195.31989694, 1162.82046332, 1076.82688101, 1059.72546079,
#        1029.08084687, 1062.16665003, 1073.34781547, 1137.81946951,
#        1064.09602465, 1097.39815462, 1078.0569022 , 1102.18064474,
#        1109.12956366, 1113.38829515, 1144.97550309, 1128.64914273,
#        1070.29103988, 1172.73433012, 1139.85333857, 1141.75349638,
#        1161.99430775, 1064.73233837, 1140.84472525, 1120.71804929,
#        1093.75385796, 1135.39209851, 1061.17526335, 1077.23074664,
#        1083.76658777, 1120.27345165, 1117.21667605, 1118.04283162,
#        1123.16499613, 1014.71380066, 1098.02180161, 1151.3684208 ,
#        1105.98096035, 1148.69320313, 1123.9911517 , 1059.3634787 ,
#        1094.88241046, 1102.56565723, 1128.78285398, 1145.7190431 ,
#        1107.31202142, 1105.81572924, 1186.23218571, 1019.20656057,
#        1175.24431667, 1030.77158698, 1098.3895413 , 1088.43839704,
#        1143.60255848, 1051.54652068, 1115.23390269, 1107.96373371,
#        1170.91678787, 1043.61542724, 1167.69478116, 1107.38542481,
#        1044.2763517 , 1101.44631689, 1070.45627099, 1080.5353689 ,
#        1094.91968792, 1043.24768756, 1070.21763648, 1126.74898492,
#        1057.95325664, 1124.73469171, 1118.86898719, 1210.35592825,
#        1034.98613189, 1163.48138777, 1125.20231975, 1117.22588821,
#        1127.87753742, 1090.54106342, 1098.46294469, 1175.49216334,
#        1084.83137785, 1120.28266381, 1162.90307888, 1111.40552179,
#        1172.98217679, 1088.35578149, 1077.97428665, 1129.55791385,
#        1091.93631572, 1145.05811864, 1052.33539879, 1091.19277571,
#        1066.21481231, 1137.37487187, 1059.56022967])

# %% [markdown]
# ### 4. Sacar métricas, valorar el modelo
#
# Recuerda que en la competición se va a evaluar con la métrica de MAE.

# %%
from sklearn.metrics import mean_squared_error
import numpy as np

print('RMSE :',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# RMSE : 705.2026860694585

# %% [markdown]
# -----------------------------------------------------------------

# %% [markdown]
# ## Una vez listo el modelo, toca predecir con el dataset de predicción

# %% [markdown]
# Definición de **modelo que está listo**.
#
# Tras hacer suficientes pruebas, analizar los datos, hacer feature engineering, probar diferentes modelos con diferentes parámetros, es con este con el que observo mejores métricas y menos overfitting. ¡Cuidado con el overfitting aquí! Si vuestro modelo aprende muy bien de estos datos pero hay overfitting cuando le pasemos los datos desconocidos de `test.csv` nos arriesgamos a que digamos, no salga lo esperado.

# %% [markdown]
# ### 1. Entrena dicho modelo con TODOS tus datos de train, esto es con `train.csv` al completo.
#
#
# **CON LAS TRANSFORMACIONES QUE LE HAYAS REALIZADO A `X` INCLUÍDAS.**
#
#
# Véase:
# - Estandarización/Normalización
# - Eliminación de Outliers
# - Eliminación de columnas
# - Creación de columnas nuevas
# - Gestión de valores nulos
# - Y un largo etcétera de técnicas que como Data Scientist hayas considerado las mejores para tu dataset.

# %% [markdown]
# ### 2. Carga los datos de `test.csv` para predecir.

# %%
X_pred = pd.read_csv("data/test.csv")
X_pred.head()
# Out:
#    laptop_ID   Company          Product            TypeName  Inches
# 0        750   Toshiba  Tecra X40-D-10G            Notebook    14.0  \
# 1        726  Mediacom    Smartbook 142            Notebook    14.0
# 2        633  Mediacom    SmartBook 140            Notebook    14.0
# 3        363      Dell    Inspiron 7577              Gaming    15.6
# 4        319      Asus    VivoBook Flip  2 in 1 Convertible    11.6
#
#                             ScreenResolution
# 0  IPS Panel Full HD / Touchscreen 1920x1080  \
# 1                IPS Panel Full HD 1920x1200
# 2                          Full HD 1920x1080
# 3                          Full HD 1920x1080
# 4                       Touchscreen 1366x768
#
#                                     Cpu  Ram              Memory
# 0            Intel Core i5 7200U 2.5GHz  8GB           256GB SSD  \
# 1              Intel Atom Z8350 1.92GHz  4GB            32GB HDD
# 2           Intel Atom x5-Z8350 1.44GHz  2GB  32GB Flash Storage
# 3           Intel Core i5 7300HQ 2.5GHz  8GB             1TB HDD
# 4  Intel Celeron Dual Core N3350 1.1GHz  2GB  32GB Flash Storage
#
#                        Gpu       OpSys  Weight
# 0    Intel HD Graphics 620  Windows 10  1.25kg
# 1    Intel HD Graphics 400  Windows 10   1.4kg
# 2        Intel HD Graphics  Windows 10   1.4kg
# 3  Nvidia GeForce GTX 1050  Windows 10  2.65kg
# 4    Intel HD Graphics 500  Windows 10   1.1kg

# %%
X_pred=X_pred[['laptop_ID','Inches']]

# %%
X_pred
# Out:
#      laptop_ID  Inches
# 0          750    14.0
# 1          726    14.0
# 2          633    14.0
# 3          363    15.6
# 4          319    11.6
# ..         ...     ...
# 386        693    15.6
# 387       1132    12.5
# 388         49    15.6
# 389       1243    15.6
# 390        924    12.5
#
# [391 rows x 2 columns]

# %% [markdown]
# **¿Por qué da error?**

# %%
predictions_submit = model.predict(X_pred)
predictions_submit
# Out:
# array([1097.6423004 , 1095.00755928, 1084.79793741, 1101.01825451,
#         981.53500887, 1062.70472731, 1123.17875843, 1136.91660235,
#        1100.68891187, 1171.05845611, 1061.49713762, 1039.67799563,
#        1120.5592512 , 1084.55112248, 1067.42530516, 1144.60126397,
#        1008.086748  , 1087.21311678, 1117.59516743, 1166.6672209 ,
#        1136.28517025, 1137.01114934, 1201.1384173 , 1195.5395924 ,
#        1155.57935199, 1095.22712104, 1205.96877603, 1141.07304191,
#        1087.734768  , 1145.58929189, 1069.84048452, 1117.48538655,
#        1169.08240026, 1183.02457206, 1166.99656354, 1048.59589281,
#        1143.28389341, 1069.57766753, 1078.759989  , 1072.74768646,
#        1196.62216731, 1063.58297435, 1030.59182845,  995.79128941,
#        1065.55903019, 1129.78084514, 1071.26763597, 1167.64001493,
#        1224.39673002, 1248.32896191, 1181.26807797, 1092.56512673,
#        1090.69885177, 1189.17230135, 1066.32749635, 1158.8727784 ,
#        1102.11606331, 1053.33170455, 1106.66997846, 1072.30856294,
#        1065.99815371, 1100.57913099, 1154.26198143, 1132.7449289 ,
#        1091.57709881, 1115.16475417, 1086.52717832, 1132.07100973,
#        1118.14407183, 1168.8628385 , 1171.60736051, 1000.2923055 ,
#        1196.51238643, 1005.56178775, 1198.39389529, 1106.068175  ,
#        1090.36950913, 1057.41120648, 1150.74899326, 1201.35797906,
#        1198.94279969, 1099.26176043, 1052.74192038, 1197.39063348,
#        1175.32467655, 1112.65502782, 1137.18906317, 1073.62593351,
#        1077.1958035 , 1138.98720518, 1055.51208827, 1124.18202024,
#        1122.86464968, 1103.26677117, 1182.03654413, 1141.11552898,
#        1162.82489009, 1101.34759715, 1194.4417836 , 1070.60895068,
#        1115.94845423, 1100.14000747, 1093.99227818, 1068.8524566 ,
#        1151.39244465, 1114.74086454, 1109.47138229, 1161.17817689,
#        1147.34578598, 1187.96471167, 1121.24518966, 1023.94970111,
#        1021.60342286, 1133.60794205, 1114.68398272, 1025.43212708,
#        1040.76378515, 1164.89549292, 1076.015467  , 1061.4402558 ,
#        1193.12441304, 1121.5745323 , 1232.19117251, 1086.90942002,
#        1158.76299752, 1179.07246037, 1077.63492702, 1099.3042475 ,
#        1086.3741422 , 1027.38253705, 1194.66134536, 1093.44337378,
#        1103.43343388, 1113.51804097, 1027.46268928, 1040.58188855,
#        1016.29466814, 1244.92575462, 1129.59894854, 1069.3188333 ,
#        1039.78777651, 1199.05258057, 1123.52333496, 1153.82285791,
#        1115.28976894, 1206.07855691, 1135.0350935 , 1084.77068424,
#        1108.37357349, 1129.67106426, 1087.51520624, 1193.23419392,
#        1058.03704851, 1018.81962839, 1094.54118258, 1085.10002688,
#        1039.77575723, 1148.55337566, 1043.08602483, 1093.00425025,
#        1131.85144797, 1191.47769984, 1171.16823699, 1197.84499089,
#        1144.05235957, 1230.21511667, 1029.82336229, 1082.13594311,
#        1008.76066717, 1086.6369592 , 1139.33178172, 1201.6873217 ,
#        1128.57325545, 1142.73498901, 1083.89243719, 1080.59901079,
#        1118.12883794, 1106.01129318, 1038.72924018, 1002.17381436,
#        1101.12803539, 1093.3335929 , 1171.71714139, 1134.06229947,
#        1232.63029603, 1115.72889247, 1104.47436085, 1151.50222553,
#         985.37733968, 1133.95251859, 1097.7248281 , 1180.93873533,
#        1119.84368409, 1183.3539147 , 1164.47160329, 1238.77802533,
#         996.99887909, 1131.53733922, 1139.86545223, 1118.69297623,
#        1094.05880382, 1098.82263691, 1005.23244511, 1083.56309455,
#        1113.18869833, 1021.48001539, 1112.92748863, 1015.55184786,
#        1121.54727912, 1053.94951007, 1005.89113039, 1137.46550675,
#        1120.22990856, 1105.76608554, 1133.73295683, 1102.55518684,
#        1162.16620481, 1231.42270635, 1067.7546478 , 1088.39345328,
#        1079.61098286, 1197.29608649, 1131.12546888, 1132.1960245 ,
#        1138.3285199 , 1079.3088934 , 1091.86318622, 1125.93851433,
#        1008.19652888, 1101.72983885, 1143.59800216, 1161.06839601,
#        1105.62905148, 1117.68971442, 1139.4415626 , 1038.27649007,
#        1178.08443245, 1071.92632125, 1121.76684088, 1129.56128338,
#        1144.62851715,  994.48915274, 1005.74529165, 1224.72607266,
#        1141.74696108, 1078.54042724, 1013.56538003, 1132.1134968 ,
#        1130.90590712, 1130.68634536, 1104.9703662 , 1128.35369369,
#        1055.59622327, 1063.91231699, 1037.19391516, 1190.27011015,
#        1119.07521793, 1108.86559606, 1027.42180951, 1148.44359478,
#        1032.54223842, 1045.82572493, 1103.13134442, 1195.10046888,
#        1105.84861324, 1108.0971299 , 1137.35572587, 1204.87096723,
#        1016.9789993 , 1071.37741685, 1177.2061854 , 1162.71510921,
#        1087.07608272, 1168.64327674, 1190.91356154, 1192.35594688,
#        1218.907686  , 1118.03429095, 1198.72323793, 1242.40079438,
#        1097.33860364, 1118.74587529, 1228.56840347, 1171.81168838,
#        1169.74108555, 1133.84273771, 1070.82851244, 1146.78164768,
#        1208.69806414, 1122.80776786, 1079.72076374, 1170.28998995,
#        1203.55359666, 1085.86849304, 1090.58907089, 1204.63617157,
#        1081.87473342, 1131.08298181, 1112.48836511, 1098.95967097,
#        1121.65706   , 1077.30558438, 1144.71104485, 1232.95963868,
#        1070.63620386, 1136.14813619, 1086.66421238, 1097.39548546,
#        1186.30276457, 1049.91326337, 1077.70145266, 1168.75305762,
#        1068.52311396, 1095.58210955, 1168.3139341 , 1067.69776597,
#        1138.76764342, 1152.42295965, 1139.82380429, 1111.11809549,
#        1086.11530798, 1090.47929001, 1124.27656723, 1173.23883982,
#        1120.66903208, 1131.52210533, 1109.60841635, 1062.37538467,
#        1184.56150438, 1116.71692039, 1079.11497752, 1124.73092465,
#        1234.05744748, 1133.51339507, 1103.21387212, 1150.63921238,
#        1140.42959052, 1089.16191945, 1016.40444902, 1178.63333685,
#        1031.5542105 , 1108.70291613, 1204.98074811, 1098.49329427,
#        1203.22425402, 1072.69478741, 1114.9604263 , 1160.72381947,
#        1070.93829332, 1143.10199681, 1124.84070553, 1144.73829803,
#        1119.35166151, 1148.77293742, 1073.35347269, 1060.53636288,
#        1103.68024882, 1136.57202582, 1229.55643139, 1126.48741873,
#        1133.45651324, 1184.34194262, 1071.59697861, 1154.68587106,
#        1111.80403396, 1072.58500653, 1159.64124456, 1180.28005005,
#        1143.42092747, 1123.19399232, 1045.20791941, 1065.22968755,
#        1214.51645079, 1186.86690286, 1191.80704248, 1094.67821664,
#        1136.47747883, 1154.06967285, 1120.01034679, 1098.21685068,
#        1021.71481104, 1041.35035471, 1012.27365534, 1097.28570458,
#        1188.62339695, 1100.24978835, 1137.24594499, 1096.58376407,
#        1066.54705812, 1197.62542913, 1073.74934098])

# %% [markdown]
# IMPORTANTE: APLICAR LO MISMO A ESTOS DATOS QUE HAYÁIS APLICADO A LOS DATOS DE ENTRENAMIENTO
#
# - SI EL ARRAY CON EL QUE HICISTEIS `.fit()` ERA DE 4 COLUMNAS, PARA `.predict()` DEBEN SER LAS MISMAS
# - SI AL ARRAY CON EL QUE HICISTEIS `.fit()` LO NORMALIZASTEIS, PARA `.predict()` DEBÉIS NORMALIZARLO
# - TODO IGUAL SALVO BORRAR FILAS, EL NÚMERO DE ROWS SE DEBE MANTENER EN ESTE SET, PUES LA PREDICCIÓN DEBE TENER 391 FILAS, SI O SI

# %% [markdown]
# **Entonces, si al cargar los datos de train usé `index_col=0` para que utilizara la primera columna del conjunto de datos como índice, ¿tendré que hacerlo también para el conjunto `test.csv`?**

# %%
# ¿Qué opináis?
# Sí

# %% [markdown]
# ![](https://www.tierraljelechu.com/web/img/wiki_up/1.996-SorpresaDto.-1-Red.jpg)

# %% [markdown]
# ### 3. AHORA puedo hacer la predicción que será lo que subirás a Kaggle.

# %% [markdown]
# **¿Qué es lo que subirás a Kaggle?**

# %%
predictions_submit = model.predict(X_pred)
predictions_submit
# Out:
# array([1097.6423004 , 1095.00755928, 1084.79793741, 1101.01825451,
#         981.53500887, 1062.70472731, 1123.17875843, 1136.91660235,
#        1100.68891187, 1171.05845611, 1061.49713762, 1039.67799563,
#        1120.5592512 , 1084.55112248, 1067.42530516, 1144.60126397,
#        1008.086748  , 1087.21311678, 1117.59516743, 1166.6672209 ,
#        1136.28517025, 1137.01114934, 1201.1384173 , 1195.5395924 ,
#        1155.57935199, 1095.22712104, 1205.96877603, 1141.07304191,
#        1087.734768  , 1145.58929189, 1069.84048452, 1117.48538655,
#        1169.08240026, 1183.02457206, 1166.99656354, 1048.59589281,
#        1143.28389341, 1069.57766753, 1078.759989  , 1072.74768646,
#        1196.62216731, 1063.58297435, 1030.59182845,  995.79128941,
#        1065.55903019, 1129.78084514, 1071.26763597, 1167.64001493,
#        1224.39673002, 1248.32896191, 1181.26807797, 1092.56512673,
#        1090.69885177, 1189.17230135, 1066.32749635, 1158.8727784 ,
#        1102.11606331, 1053.33170455, 1106.66997846, 1072.30856294,
#        1065.99815371, 1100.57913099, 1154.26198143, 1132.7449289 ,
#        1091.57709881, 1115.16475417, 1086.52717832, 1132.07100973,
#        1118.14407183, 1168.8628385 , 1171.60736051, 1000.2923055 ,
#        1196.51238643, 1005.56178775, 1198.39389529, 1106.068175  ,
#        1090.36950913, 1057.41120648, 1150.74899326, 1201.35797906,
#        1198.94279969, 1099.26176043, 1052.74192038, 1197.39063348,
#        1175.32467655, 1112.65502782, 1137.18906317, 1073.62593351,
#        1077.1958035 , 1138.98720518, 1055.51208827, 1124.18202024,
#        1122.86464968, 1103.26677117, 1182.03654413, 1141.11552898,
#        1162.82489009, 1101.34759715, 1194.4417836 , 1070.60895068,
#        1115.94845423, 1100.14000747, 1093.99227818, 1068.8524566 ,
#        1151.39244465, 1114.74086454, 1109.47138229, 1161.17817689,
#        1147.34578598, 1187.96471167, 1121.24518966, 1023.94970111,
#        1021.60342286, 1133.60794205, 1114.68398272, 1025.43212708,
#        1040.76378515, 1164.89549292, 1076.015467  , 1061.4402558 ,
#        1193.12441304, 1121.5745323 , 1232.19117251, 1086.90942002,
#        1158.76299752, 1179.07246037, 1077.63492702, 1099.3042475 ,
#        1086.3741422 , 1027.38253705, 1194.66134536, 1093.44337378,
#        1103.43343388, 1113.51804097, 1027.46268928, 1040.58188855,
#        1016.29466814, 1244.92575462, 1129.59894854, 1069.3188333 ,
#        1039.78777651, 1199.05258057, 1123.52333496, 1153.82285791,
#        1115.28976894, 1206.07855691, 1135.0350935 , 1084.77068424,
#        1108.37357349, 1129.67106426, 1087.51520624, 1193.23419392,
#        1058.03704851, 1018.81962839, 1094.54118258, 1085.10002688,
#        1039.77575723, 1148.55337566, 1043.08602483, 1093.00425025,
#        1131.85144797, 1191.47769984, 1171.16823699, 1197.84499089,
#        1144.05235957, 1230.21511667, 1029.82336229, 1082.13594311,
#        1008.76066717, 1086.6369592 , 1139.33178172, 1201.6873217 ,
#        1128.57325545, 1142.73498901, 1083.89243719, 1080.59901079,
#        1118.12883794, 1106.01129318, 1038.72924018, 1002.17381436,
#        1101.12803539, 1093.3335929 , 1171.71714139, 1134.06229947,
#        1232.63029603, 1115.72889247, 1104.47436085, 1151.50222553,
#         985.37733968, 1133.95251859, 1097.7248281 , 1180.93873533,
#        1119.84368409, 1183.3539147 , 1164.47160329, 1238.77802533,
#         996.99887909, 1131.53733922, 1139.86545223, 1118.69297623,
#        1094.05880382, 1098.82263691, 1005.23244511, 1083.56309455,
#        1113.18869833, 1021.48001539, 1112.92748863, 1015.55184786,
#        1121.54727912, 1053.94951007, 1005.89113039, 1137.46550675,
#        1120.22990856, 1105.76608554, 1133.73295683, 1102.55518684,
#        1162.16620481, 1231.42270635, 1067.7546478 , 1088.39345328,
#        1079.61098286, 1197.29608649, 1131.12546888, 1132.1960245 ,
#        1138.3285199 , 1079.3088934 , 1091.86318622, 1125.93851433,
#        1008.19652888, 1101.72983885, 1143.59800216, 1161.06839601,
#        1105.62905148, 1117.68971442, 1139.4415626 , 1038.27649007,
#        1178.08443245, 1071.92632125, 1121.76684088, 1129.56128338,
#        1144.62851715,  994.48915274, 1005.74529165, 1224.72607266,
#        1141.74696108, 1078.54042724, 1013.56538003, 1132.1134968 ,
#        1130.90590712, 1130.68634536, 1104.9703662 , 1128.35369369,
#        1055.59622327, 1063.91231699, 1037.19391516, 1190.27011015,
#        1119.07521793, 1108.86559606, 1027.42180951, 1148.44359478,
#        1032.54223842, 1045.82572493, 1103.13134442, 1195.10046888,
#        1105.84861324, 1108.0971299 , 1137.35572587, 1204.87096723,
#        1016.9789993 , 1071.37741685, 1177.2061854 , 1162.71510921,
#        1087.07608272, 1168.64327674, 1190.91356154, 1192.35594688,
#        1218.907686  , 1118.03429095, 1198.72323793, 1242.40079438,
#        1097.33860364, 1118.74587529, 1228.56840347, 1171.81168838,
#        1169.74108555, 1133.84273771, 1070.82851244, 1146.78164768,
#        1208.69806414, 1122.80776786, 1079.72076374, 1170.28998995,
#        1203.55359666, 1085.86849304, 1090.58907089, 1204.63617157,
#        1081.87473342, 1131.08298181, 1112.48836511, 1098.95967097,
#        1121.65706   , 1077.30558438, 1144.71104485, 1232.95963868,
#        1070.63620386, 1136.14813619, 1086.66421238, 1097.39548546,
#        1186.30276457, 1049.91326337, 1077.70145266, 1168.75305762,
#        1068.52311396, 1095.58210955, 1168.3139341 , 1067.69776597,
#        1138.76764342, 1152.42295965, 1139.82380429, 1111.11809549,
#        1086.11530798, 1090.47929001, 1124.27656723, 1173.23883982,
#        1120.66903208, 1131.52210533, 1109.60841635, 1062.37538467,
#        1184.56150438, 1116.71692039, 1079.11497752, 1124.73092465,
#        1234.05744748, 1133.51339507, 1103.21387212, 1150.63921238,
#        1140.42959052, 1089.16191945, 1016.40444902, 1178.63333685,
#        1031.5542105 , 1108.70291613, 1204.98074811, 1098.49329427,
#        1203.22425402, 1072.69478741, 1114.9604263 , 1160.72381947,
#        1070.93829332, 1143.10199681, 1124.84070553, 1144.73829803,
#        1119.35166151, 1148.77293742, 1073.35347269, 1060.53636288,
#        1103.68024882, 1136.57202582, 1229.55643139, 1126.48741873,
#        1133.45651324, 1184.34194262, 1071.59697861, 1154.68587106,
#        1111.80403396, 1072.58500653, 1159.64124456, 1180.28005005,
#        1143.42092747, 1123.19399232, 1045.20791941, 1065.22968755,
#        1214.51645079, 1186.86690286, 1191.80704248, 1094.67821664,
#        1136.47747883, 1154.06967285, 1120.01034679, 1098.21685068,
#        1021.71481104, 1041.35035471, 1012.27365534, 1097.28570458,
#        1188.62339695, 1100.24978835, 1137.24594499, 1096.58376407,
#        1066.54705812, 1197.62542913, 1073.74934098])

# %% [markdown]
# **¡PERO! Para subir a Kaggle la predicción, ésta tendrá que tener una forma específica y no valdrá otra.**
#
# En este caso, la **MISMA** forma que `sample_submission.csv`.

# %%
sample = pd.read_csv("data/sample_submission.csv")

# %%
sample.head()
# Out:
#    laptop_ID  Price_euros
# 0        750          500
# 1        726          500
# 2        633          500
# 3        363          650
# 4        319          650

# %%
sample.shape
# Out:
# (391, 2)

# %% [markdown]
# ### 4. Mete tus predicciones en un dataframe.
#
# En este caso, la **MISMA** forma que `sample_submission.csv`.

# %%
submission = pd.DataFrame({"laptop_ID": sample['laptop_ID'], "Price_euros": predictions_submit})

# %%
submission.head()
# Out:
#    laptop_ID  Price_euros
# 0        750  1097.642300
# 1        726  1095.007559
# 2        633  1084.797937
# 3        363  1101.018255
# 4        319   981.535009

# %%
submission.shape
# Out:
# (391, 2)

# %% [markdown]
# ### 5. Pásale el CHEQUEATOR para comprobar que efectivamente está listo para subir a Kaggle.

# %%
def chequeator(df_to_submit):
    """
    Esta función se asegura de que tu submission tenga la forma requerida por Kaggle.
    
    Si es así, se guardará el dataframe en un `csv` y estará listo para subir a Kaggle.
    
    Si no, LEE EL MENSAJE Y HAZLE CASO.
    
    Si aún no:
    - apaga tu ordenador, 
    - date una vuelta, 
    - enciendelo otra vez, 
    - abre este notebook y 
    - leelo todo de nuevo. 
    Todos nos merecemos una segunda oportunidad. También tú.
    """
    if df_to_submit.shape == sample.shape:
        if df_to_submit.columns.all() == sample.columns.all():
            if df_to_submit.laptop_ID.all() == sample.laptop_ID.all():
                print("You're ready to submit!")
                submission.to_csv("submission.csv", index = False) #muy importante el index = False
                urllib.request.urlretrieve("https://i.kym-cdn.com/photos/images/facebook/000/747/556/27a.jpg", "gfg.png")     
                img = Image.open("gfg.png")
                img.show()   
            else:
                print("Check the ids and try again")
        else:
            print("Check the names of the columns and try again")
    else:
        print("Check the number of rows and/or columns and try again")
        print("\nMensaje secreto de Clara: No me puedo creer que después de todo este notebook hayas hecho algún cambio en las filas de `diamonds_test.csv`. Lloro.")

# %%
chequeator(submission)
# Out:
# You're ready to submit!
