# %%
import pandas as pd

# %%
df = pd.read_csv('D:\Descargas\diccionario_de_datos\diccionario_datos_mopradef_2022_11.csv')
df
# Out:
#                                          NOMBRE_CAMPO  LONGITUD TIPO  \
# 0                                              Folio          6    C
# 1                                            Entidad          2    C
# 2                                            Control          5    C
# 3                              Vivienda seleccionada          1    C
# 4                                    Número de hogar          1    C
# 5                                       Hogar mudado          1    C
# 6          Número de renglón del informante elegido           2    C
# 7                           Ciudad autorrepresentada          2    N
# 8                                            Periodo          4    C
# 9                                                Sexo         1    C
# 10                                               Edad         2    N
# 11                               Nivel de instrucción         2    C
# 12       ¿Hasta que año o grado aprobó en la escuela?         1    C
# 13                               ¿La semana pasada…           2    N
# 14  1. ¿En su tiempo libre practica algún deporte ...         1    N
# 15  2. ¿Alguna vez usted practicó deporte o ejerci...         1    N
# 16  3. ¿Cuál es la razón principal por la que uste...         1    N
# 17  3. ¿Cuál es la razón principal por la que uste...       250    C
# 18  4. ¿Cuál es la razón principal por la que uste...         1    N
# 19  4. ¿Cuál es la razón principal por la que uste...       250    C
# 20  5. ¿Ha pensado en realizar deporte o ejercicio...         1    N
# 21  6. ¿Qué necesita usted para realizar deporte o...         1    N
# 22  6. ¿Qué necesita usted para realizar deporte o...       250    C
# 23                                 7. ¿Usted realiza…         1    N
# 24  8. De lunes a domingo de la semana pasada, ¿cu...         1    N
# 25  9. Aproximadamente, ¿cuántos minutos realizó (...         3    N
# 26  10. ¿La intensidad de esta práctica fue princi...         1    N
# 27  11. ¿Principalmente en dónde realiza usted (de...         1    N
# 28  11. ¿Principalmente en dónde realiza usted (de...       250    C
# 29  12. ¿En qué momento del día usted realiza (dep...         1    N
# 30  12. ¿En qué momento del día usted realiza (dep...         1    N
# 31  12. ¿En qué momento del día usted realiza (dep...         1    N
# 32  12. ¿En qué momento del día usted realiza (dep...         1    N
# 33  13. ¿Cuál es el motivo principal por el que us...         1    N
# 34  13. ¿Cuál es el motivo principal por el que us...       250    C
# 35  14. La principal influencia para que usted rea...         1    N
# 36  14. La principal influencia para que usted rea...       250    C
# 37  15. ¿Con quién acostumbra usted realizar (depo...         1    N
# 38  16. ¿Hay instalaciones o lugares públicos en s...         1    N
# 39  17. ¿Esas instalciones o lugares públicos se e...         1    N
# 40  18. ¿Cuál es la razón principal por la que ust...         1    N
# 41  18. ¿Cuál es la razón principal por la que ust...       250    C
# 42                                     observaciones        250    C
# 43  Tiempo total semanal de practica fisico-deport...         5    N
# 44                        Actividad físico-deportiva          3    C
# 45                                     Factor elegido        10    N
# 46                        Unidad primaria de muestreo         5    C
# 47                         Estrato de diseño muestral         3    N
#
#      MNEMÓNICO    CATÁLOGO                                    RANGO_CLAVES
# 0        folio         NaN  1 Zona, 1 - 3 Estrato, Últimos 4 panel de rota...
# 1      entidad    entidad                                             01...32
# 2      control         NaN                                        40001…41415
# 3      viv_sel    viv_sel                                                 1…9
# 4      num_hog     num_hog                                                1…9
# 5      hog_mud    hog_mud                                               1...3
# 6    n_ren_ele   n_ren_ele                                              01…12
# 7           cd          cd                                               1…43
# 8      periodo         per                                           01…12 22
# 9         sexo       sexo                                                1, 2
# 10        edad       edad                                                0…99
# 11       nivel       nivel                                 00…09, 99, blanco
# 12        anio       anio                                      1…8, 9, blanco
# 13  cond_activ  cond_activ                                            1…10,99
# 14          p1     c_si_no                                               1, 2
# 15          p2   c_si_no_b                                      1, 2, blanco
# 16          p3         cp3                                       1…9, blanco
# 17     p3_8esp         NaN                                  a…z, 1…9, blanco
# 18          p4         cp4                                       1…9, blanco
# 19     p4_8esp         NaN                                  a…z, 1…9, blanco
# 20          p5   c_si_no_b                                      1, 2, blanco
# 21          p6        cp6                                  1…4, 8, 9, blanco
# 22     p6_8esp         NaN                                  a…z, 1…9, blanco
# 23          p7         cp7                                       1…3, blanco
# 24          p8         cp8                                       1…8, blanco
# 25          p9         cp9                                   001…999, blanco
# 26         p10        cp10                                      1, 2, blanco
# 27         p11        cp11                                    1…6, 8, blanco
# 28    p11_8esp         NaN                                  a…z, 1…9, blanco
# 29       p12_1      cp12_1                                         1, blanco
# 30       p12_2      cp12_2                                         2, blanco
# 31       p12_3      cp12_3                                         3, blanco
# 32       p12_4      cp12_4                                         4, blanco
# 33         p13        cp13                                    1…4, 8, blanco
# 34    p13_8esp         NaN                                  a…z, 1…9, blanco
# 35         p14        cp14                                       1…8, blanco
# 36    p14_8esp         NaN                                  a…z, 1…9, blanco
# 37         p15        cp15                                       1…4, blanco
# 38         p16  c_si_no_ns                                   1, 2, 9, blanco
# 39         p17        cp17                                    1…3, 9, blanco
# 40         p18        cp18                                 1…3, 8, 9, blanco
# 41    p18_8esp         NaN                                  a…z, 1…9, blanco
# 42         obs         NaN                                  a…z, 1…9, blanco
# 43   tipracsem  ctipracsem                                    9…1260, blanco
# 44      actfis     cactfis                             01, 02, 11…13, blanco
# 45      factor         NaN                                         1523…90271
# 46     upm_dis         NaN                                        00001…00582
# 47     est_dis         NaN                                              1...4

# %%
for i in df['NOMBRE_CAMPO']:
    print(i)
# Out:
# Folio
# Entidad
# Control
# Vivienda seleccionada
# Número de hogar
# Hogar mudado
# Número de renglón del informante elegido
# Ciudad autorrepresentada
# Periodo
# Sexo
# Edad
# Nivel de instrucción
#  ¿Hasta que año o grado aprobó en la escuela?
#  ¿La semana pasada…
# 1. ¿En su tiempo libre practica algún deporte o ejercicio físico, como fútbol, basquetbol, aeróbics, bicicleta, caminar u otro?
# 2. ¿Alguna vez usted practicó deporte o ejercicio físico?
# 3. ¿Cuál es la razón principal por la que usted abandonó la práctica de deporte o ejercicio físico?
# 3. ¿Cuál es la razón principal por la que usted abandonó la práctica de deporte o ejercicio físico? Especifique
# 4. ¿Cuál es la razón principal por la que usted no practica deporte ni ejercicio físico?
# 4. ¿Cuál es la razón principal por la que usted no practica deporte ni ejercicio físico?Especifique
# 5. ¿Ha pensado en realizar deporte o ejercicio físico próximamente?
# 6. ¿Qué necesita usted para realizar deporte o ejercicio físico?
# 6. ¿Qué necesita usted para realizar deporte o ejercicio físico? Especifique
# 7. ¿Usted realiza…
# 8. De lunes a domingo de la semana pasada, ¿cuántos días realizó usted (deporte/ejercicio físico/deporte y ejercicio físico)
# 9. Aproximadamente, ¿cuántos minutos realizó (deporte/ejercicio físico/deporte y ejercicio físico) por día?
# 10. ¿La intensidad de esta práctica fue principalmente…
# 11. ¿Principalmente en dónde realiza usted (deporte/ejercicio físico/deporte y ejercicio físico) por día ?
# 11. ¿Principalmente en dónde realiza usted (deporte/ejercicio físico/deporte y ejercicio físico) por día ? Especifique
# 12. ¿En qué momento del día usted realiza (deporte/ejercicio físico/deporte y ejercicio físico)? En la mañana
# 12. ¿En qué momento del día usted realiza (deporte/ejercicio físico/deporte y ejercicio físico)? En la tarde
# 12. ¿En qué momento del día usted realiza (deporte/ejercicio físico/deporte y ejercicio físico)? En la noche
# 12. ¿En qué momento del día usted realiza (deporte/ejercicio físico/deporte y ejercicio físico)? En cualquier momento del día
# 13. ¿Cuál es el motivo principal por el que usted realiza (deporte/ejercicio físico/deporte y ejercicio físico)?
# 13. ¿Cuál es el motivo principal por el que usted realiza (deporte/ejercicio físico/deporte y ejercicio físico)? Especifique
# 14. La principal influencia para que usted realice (deporte/ejercicio físico/deporte y ejercicio físico), ¿fue por parte de…
# 14. La principal influencia para que usted realice (deporte/ejercicio físico/deporte y ejercicio físico), ¿fue por parte de… Especifique
# 15. ¿Con quién acostumbra usted realizar (deporte/ejercicio físico/deporte y ejercicio físico)?
# 16. ¿Hay instalaciones o lugares públicos en su colonia para realizar deporte o ejercicio físico?
# 17. ¿Esas instalciones o lugares públicos se encuentran en condiciones…
# 18. ¿Cuál es la razón principal por la que usted no realizó deporte ni ejercicio físico la semana pasada?
# 18. ¿Cuál es la razón principal por la que usted no realizó deporte ni ejercicio físico la semana pasada? Especifique
# observaciones
# Tiempo total semanal de practica fisico-deportiva (MINUTOS)
# Actividad físico-deportiva
# Factor elegido
# Unidad primaria de muestreo
# Estrato de diseño muestral

# %%
pd.read_csv(r'D:\Documentos\2.CURSOS\BOOTCAMP\DS_PT_09_2023\EDA\Encuesta_1\conjunto_de_datos\conjunto_de_datos_mopradef_2022_11.csv', sep =',', encoding='latin-1')
# Out:
#        folio  entidad  control  viv_sel  num_hog  hog_mud  n_ren_ele  cd  \
# 0     11B213        1    40003        4        1        0          1  14
# 1     11B213        1    40003        3        1        0          2  14
# 2     11B213        1    40003        1        1        0          1  14
# 3     11B213        1    40003        2        1        0          1  14
# 4     12A204        1    40005        3        1        0          1  14
# ...      ...      ...      ...      ...      ...      ...        ...  ..
# 1976  12A206       32    40325        1        1        0          2  32
# 1977  12A206       32    40325        3        1        0          2  32
# 1978  12B212       32    40385        4        1        0          2  32
# 1979  12B212       32    40385        3        1        0          1  32
# 1980  12B212       32    40385        2        1        0          1  32
#
#       periodo  sexo  ...  p16  p17  p18  p18_8esp  obs  tipracsem  actfis  \
# 0        1122     2  ...    1    1    0       NaN  NaN         90      12
# 1        1122     2  ...    0    0    0       NaN  NaN          0       1
# 2        1122     1  ...    0    0    0       NaN  NaN          0       1
# 3        1122     1  ...    0    0    0       NaN  NaN          0       1
# 4        1122     1  ...    0    0    0       NaN  NaN          0       1
# ...       ...   ...  ...  ...  ...  ...       ...  ...        ...     ...
# 1976     1122     2  ...    2    0    0       NaN  NaN        200      11
# 1977     1122     2  ...    2    0    0       NaN  NaN        180      11
# 1978     1122     2  ...    0    0    3       NaN  NaN          0      13
# 1979     1122     2  ...    1    1    0       NaN  NaN        630      11
# 1980     1122     2  ...    2    0    0       NaN  NaN        120      12
#
#      factor  upm_dis est_dis
# 0      7381        1       2
# 1     32378        1       2
# 2      6385        1       2
# 3      8624        1       2
# 4     34576        2       3
# ...     ...      ...     ...
# 1976  13486      581       3
# 1977  23286      581       3
# 1978  17756      582       3
# 1979  17154      582       3
# 1980  12993      582       3
#
# [1981 rows x 48 columns]

# %%
pd.read_csv(r'D:\Documentos\2.CURSOS\BOOTCAMP\DS_PT_09_2023\EDA\Encuesta_2\practica_deporte_ultimo_año_seg_SESP.csv', encoding= 'latin-1', on_bad_lines='skip',header= 2)
# Out:
#                                            Unnamed: 0  \
# 0                                               TOTAL
# 1                                             Hombres
# 2                                             Mujeres
# 3                                    De 15 a 19 anios
# 4                                    De 20 a 24 anios
# 5                                    De 25 a 34 anios
# 6                                    De 35 a 44 anios
# 7                                    De 45 a 54 anios
# 8                                    De 55 a 64 anios
# 9                                    De 65 a 74 anios
# 10                            De 75 anios en adelante
# 11       Sit. personal: Soltero en casa de sus padres
# 12        Sit. personal: Casado o en pareja sin hijos
# 13  Sit. personal: Casado o en pareja con hijos me...
# 14  Sit. personal: Casado o en pareja con hijos de...
# 15  Sit. personal: Casado o en pareja viviendo sol...
# 16                               Sit. personal: Otros
#
#     Total practicaron en el ultimo anio  Todos los dias  \
# 0                                  57.3            23.8
# 1                                  63.1            27.0
# 2                                  51.8            20.7
# 3                                  84.4            45.9
# 4                                  81.4            39.3
# 5                                  74.6            28.4
# 6                                  69.3            24.7
# 7                                  61.2            22.6
# 8                                  49.7            21.1
# 9                                  37.8            17.9
# 10                                 16.2             8.3
# 11                                 79.2            38.3
# 12                                 56.2            24.8
# 13                                 67.3            20.9
# 14                                 47.6            20.2
# 15                                 39.0            16.5
# 16                                 42.5            19.1
#
#     Al menos una vez a la semana  Al menos una vez al mes  \
# 0                           52.5                     56.2
# 1                           57.5                     62.0
# 2                           47.7                     50.7
# 3                           81.7                     84.2
# 4                           73.8                     79.8
# 5                           67.6                     73.3
# 6                           61.8                     67.9
# 7                           55.7                     59.8
# 8                           46.1                     48.7
# 9                           35.1                     37.0
# 10                          14.9                     15.4
# 11                          73.6                     78.1
# 12                          52.5                     55.3
# 13                          59.8                     65.8
# 14                          44.0                     46.9
# 15                          35.4                     37.7
# 16                          38.3                     41.4
#
#     Al menos una vez al trimestre  Total practicaron en el ultimo anio.1  \
# 0                            56.7                                  100.0
# 1                            62.5                                  100.0
# 2                            51.2                                  100.0
# 3                            84.4                                  100.0
# 4                            80.9                                  100.0
# 5                            74.1                                  100.0
# 6                            68.5                                  100.0
# 7                            60.6                                  100.0
# 8                            48.9                                  100.0
# 9                            37.0                                  100.0
# 10                           15.6                                  100.0
# 11                           78.7                                  100.0
# 12                           55.7                                  100.0
# 13                           66.5                                  100.0
# 14                           47.0                                  100.0
# 15                           38.1                                  100.0
# 16                           41.4                                  100.0
#
#     Todos los dias.1  Al menos una vez a la semana.1  \
# 0               41.5                            91.5
# 1               42.8                            91.0
# 2               39.9                            92.1
# 3               54.4                            96.9
# 4               48.3                            90.7
# 5               38.0                            90.6
# 6               35.6                            89.2
# 7               37.0                            91.0
# 8               42.5                            92.8
# 9               47.5                            93.0
# 10              51.0                            91.9
# 11              48.3                            92.9
# 12              44.0                            93.3
# 13              31.1                            88.9
# 14              42.4                            92.4
# 15              42.3                            90.7
# 16              45.0                            90.2
#
#     Al menos una vez al mes.1  Al menos una vez al trimestre.1  Unnamed: 11
# 0                        98.0                             98.9          NaN
# 1                        98.1                             98.9          NaN
# 2                        97.9                             98.8          NaN
# 3                        99.8                            100.0          NaN
# 4                        98.1                             99.4          NaN
# 5                        98.2                             99.3          NaN
# 6                        97.9                             98.8          NaN
# 7                        97.7                             98.9          NaN
# 8                        98.0                             98.4          NaN
# 9                        97.8                             98.0          NaN
# 10                       94.9                             96.1          NaN
# 11                       98.7                             99.3          NaN
# 12                       98.4                             99.1          NaN
# 13                       97.7                             98.7          NaN
# 14                       98.6                             98.8          NaN
# 15                       96.7                             97.6          NaN
# 16                       97.4                             97.4          NaN
